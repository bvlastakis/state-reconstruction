# %%
# %pylab inline

import bootstrap as bs
reload(bs)

path = "sample_data/XE.txt"
basis = 10

blah = bs.BS_residual(basis = 10, method = 'minimize')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
blah.iniReconstruction(path)

# %%
blah.plotResidual()
# Out:
#                  0
# count  1323.000000
# mean     -0.003269
# std       0.028660
# min      -0.105160
# 25%      -0.021671
# 50%      -0.000944
# 75%       0.015917
# max       0.097126
#
# [8 rows x 1 columns]

# %%
blah.residualBootstrap()
blah.plotBootstrap()
